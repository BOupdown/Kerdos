# %%
import os
import json

# %%
def load_json_files(base_directory):
    json_files = []
    for root, dirs, files in os.walk(base_directory):
        for file in files:
            if file.endswith(".json"):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    json_data = json.load(f)
                    json_files.append({
                        'file_path': file_path,
                        'data': json_data
                    })
    return json_files

base_directory = 'export_v4/fiches/solution'
json_files = load_json_files(base_directory)

# %%
def extract_french_titles(json_files):
    french_titles = {}
    for json_file in json_files:
        identifier = json_file['data']['identifier']
        french_title = json_file['data']['languages']['fr']['title']
        french_titles[identifier] = french_title
    return french_titles

titles = extract_french_titles(json_files)
print(titles)
# Out:
# {'328': 'Fonctionnement du moteur à pleine charge', '145': "Production d'air décentralisée", '1117': 'Moteur à haut rendement IE4 (super premium)', '1585': 'Evaluer la durée de ventilation d’un palier', '297': "Programmateur d'intermittence sur une chaudière existante pour un chauffage central à combustible", '373': "Gestion technique d'un bâtiment (GTB)", '572': 'Caisson de ventilation mécanique contrôlée (VMC) à consommation réduite', '295': "Chauffage et la climatisation adaptés à l'occupation des locaux", '1091': "Passer à une coulée continue pour la production d'acier.", '231': 'Système de télésurveillance et de télégestion', '72': "Vérification de l'usure des pompes, et identification des pompes en cavitation.", '262': "Vérification de la présence de traces d'humidité", '129': 'Nouveaux onduleur en remplacement des anciens onduleurs', '181': 'Utilisation de turbines à contre pression à la place des soupapes de réduction de pression', '1039': 'Optimisation de la pression de fonctionnement', '1558': "Optimisation de l'orientation des façades vitrées", '389': "Groupe de production d'eau glacée avec condenseur sur eau", '324': 'Réaction face aux pannes répétées', '361': 'Réduction des pertes de chaleur par les ouvertures du four', '1093': 'Système de purges automatique sur les tours de refroidissement', '1125': 'Gestion du poste pneumatique dans une flotte de poids lourds', '727': 'Système de maîtrise de la puissance réactive en éclairage extérieur', '400': 'Lampes à iodures métalliques à brûleur céramique en remplacement de lampe à vapeur de mercure', '219': 'Turbine de détente pour récupérer le contenu énergétique de gaz sous pression', '1036': "Récupération de chaleur lorsque le produit se refroidit à l'air", '449': "Formation du personnel à l'utilisation rationnelle de l'énergie", '1025': 'Récupération de la chaleur des tours de séchage', '1693': 'Remplacer les groupes froids', '201': "Ajout ou réparation des réfractaires d'une chaudière vapeur", '1010': 'Système de commande prédictive sur un four', '1645': 'Optimisation du tracé du réseau de chaleur', '925': "Electrovanne pour l'optimisation de la régulation", '1123': 'Remotorisation d’une unité de transport fluvial', '208': "Minimisation des purges de la chaudière en améliorant le traitement de l'eau", '172': 'Filtration et séchage au minimum requis', '349': "Récupération de la chaleur des fumées pour production d'eau chaude et génération de froid", '29': 'Nettoyage des condenseurs et autres échangeurs', '805': 'Regroupement de plusieurs sites pour réduire les flux de camions', '443': 'Utilisation des DJU pour analyser le chauffage.', '1017': "Récupération de chaleur pour préchauffer l'air comburant", '1072': 'Récupération des vapeurs des produits chimiques', '513': 'Gestion quotidienne du fonctionnement', '379': 'Ventilation mécanique modulée proportionnelle', '59': 'Lubrification correcte des paliers conformément aux spécifications constructeur', '1448': 'Panneau solaire photovoltaïque monocristallin, avec tracker 1 axe, raccordé au réseau', '239': "Consignes au personnel pour l'extinction des lumières des pièces non occupées ou des couloirs", '486': "Vérification de l'adéquation des cycles thermiques avec les produits", '544': 'Chaudière collective à condensation', '376': "Isolation d'un réseau d'eau chaude sanitaire existant", '820': 'Pompe à chaleur à absorption de type air/eau ou eau/eau', '1709': 'Faire une étude carbone des préconisations', '41': 'Mise en route graduelle des ventilateurs sur les aérocondenseurs', '345': 'Vérification de la puissance réactive', '1622': 'Machine frigorifique à compression bi-étagée', '114': 'Filtres anti-harmoniques proche des sources très polluantes', '1128': 'Optimisation du réseau de chauffage', '31': 'Purge règulière des incondensables', '104': 'Pompe à chaleur haute température pour valoriser la vapeur basse pression', '530': 'Réfrigérateur domestique performant', '265': "Asservissement du chauffage à l'ouverture des portes  ...

# %%
def link_titles_to_md_files(base_directory, titles):
    linked_files = []
    for root, dirs, files in os.walk(base_directory):
        if os.path.basename(root) == 'FRENCH':
            for file in files:
                if file.endswith(".md"):
                    file_path = os.path.join(root, file)
                    # Extraire l'identifiant du dossier parent
                    identifier = os.path.basename(os.path.dirname(root))
                    if identifier in titles:
                        # Lire le contenu du fichier .md
                        with open(file_path, 'r', encoding='utf-8') as f:
                            content = f.read()

                        linked_files.append({  # Ajouter un objet complet avec l'identifiant
                            "identifier": identifier,
                            'content': content,
                            "title": titles[identifier]
                        })
    return linked_files

linked_files = link_titles_to_md_files(base_directory, titles)


# Sauvegarder les données dans un fichier JSON
output_file = 'linked_files.json'
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(linked_files, f, ensure_ascii=False, indent=4)

print(f"Les données ont été sauvegardées dans {output_file}")
# Out:
# Les données ont été sauvegardées dans linked_files.json
